# %%
import requests 
import csv
import json
import pandas as pd
from datetime import datetime, timezone
import os
from pathlib import Path

# %%
# declaring the output path
output_path = "D:/products/ALERT_DTC_DOWNLOAD"

# %%
# internal functions being used
def trip_data_download(vehicle_id, start_ts, end_ts):
    trip_url = 'http://internal-apis.intangles.com/trips/' + str(vehicle_id) + '/gettripsintime/' + str(start_ts) + '/' + str(end_ts) + '?proj=_id,start_time,end_time'
    # getting the trip-data
    trip_response = requests.get(trip_url, json=trip_url)
    if trip_response.status_code == 200:
        # Parse the JSON response
        trip_json_data = trip_response.json()
        return trip_json_data['result']
    return []

def fetch_dtc_data(start_ts, end_ts, vehicle_id):
    
    df_all_dtcs = pd.DataFrame()
    start_batch_time = start_ts 
    end_batch_time = start_batch_time + 24*1*60*60*1000 

    
    while end_batch_time <= end_ts:
        print("starting timestamp ", start_batch_time) 
        print("ending timestamp ", end_batch_time)
        headers = {
                'Content-Type': 'application/json',
            }
        vehicle_dtc_data = {"report": "default",
            "filter":[
                {
                    "fault_log.timestamp":{
                        "gt": start_batch_time,
                        "lt": end_batch_time
                    }
                },
                {
                    "fault_log.vehicle_id" : vehicle_id
                }
            ],
            "select":{
                "fault_log.status":{
                    "value":True,
                    "as":"status"
                },
                "fault_log.code":{
                    "value":True,
                    "as":"code"
                },
                "fault_code.severity":{
                    "value":True,
                    "as":"severity"
                },
                "vehicle.id":{
                    "value":True,
                    "as":"vehicle_id"
                },
                "fault_log.vehicle_id":{
                    "value":True,
                    "as":"vehicle_id1"
                },
                "vehicle.account_id": {
                    "value": True,
                    "as": "account_id"
                },
                "vehicle.tag":{
                    "value":True,
                    "as":"vehicle_plate"
                },
                "fault_log.timestamp":{
                    "value":True,
                    "as":"time"
                },
                "spec.manufacturer":{
                    "value":True,
                    "as":"manufacturer"
                },
                "spec.max_load_capacity":{
                    "value":True,
                    "as": "max_load_capacity"
                },
                "fault_code.description":{
                    "value":True,
                    "as":"description"
                }
            }
            }
        dtc_url = 'http://internal-apis.intangles.com/dashboard_apis/fetch'
        dtc_response = requests.post(dtc_url, json=vehicle_dtc_data, headers=headers)
        print(dtc_response)
        dtc_csv_filename = 'dtc.csv'
        if dtc_response.status_code == 200:
            # Parse the JSON response
            dtc_json_data = dtc_response.json()
            dtc_headers = dtc_json_data['result']['fields']
            with open(dtc_csv_filename, 'w', newline='') as csv_file:
                csv_writer = csv.DictWriter(csv_file, fieldnames=dtc_headers)
                
                # Write headers to the CSV file
                csv_writer.writeheader()
                
                # Write each JSON item as a row in the CSV file
                csv_writer.writerows(dtc_json_data['result']['output'])
        else:
            print(f"Failed to fetch the dtc data. Status code: {dtc_response.status_code}")
        df_dtc = pd.read_csv(dtc_csv_filename, encoding='unicode_escape') 

        start_batch_time += 24*1*60*60*1000 
        end_batch_time = start_batch_time + 24*1*60*60*1000

        df_all_dtcs= pd.concat([df_all_dtcs, df_dtc], ignore_index=True)

    return df_all_dtcs



def fetch_alert_data(start_ts, end_ts, vehicle_id):
    
   

        headers = {
            'Content-Type': 'application/json',
        }


        vehicle_alert_data = {
            "report": "dafault",
            "filter": [
                {
                    "alert_algo_output.timestamp": {
                        "gt": start_ts,
                        "lt": end_ts
                    }
                },
                {
                    "vehicle.id" : vehicle_id
                }
               
    
            ],
            "select": {
                "alert_algo_output.account_id": {
                    "value": True,
                    "as": "account_id"
                },
                "alert_algo_output.vehicle_id": {
                    "value": True,
                    "as": "vehicle_id"
                },
                "alert_algo_output.severity": {
                    "value": True,
                    "as": "severity"
                },
                "alert_algo_output.alerts": {
                    "value": True,
                    "as": "alert_name"
                },
                "alert_algo_output.timestamp": {
                    "value": True,
                    "as": "time"
                },
                "vehicle.spec_id":{
                    "value":True,
                    "as":"spec_id"
                },
                "spec.model":{
                    "value":True,
                    "as":"model"
                },
                "spec.manufacturer":{
                    "value":True,
                    "as":"manufacturer"
                },
                "spec.max_load_capacity":{
                    "value":True,
                    "as":"max_load_capacity"
                },
                
                "vehicle.id":{
                    "value":True,
                    "as":"vehicle_id"
                }
            }
        }

        

        alert_url = 'http://internal-apis.intangles.com/dashboard_apis/fetch'

        # getting the alert-data
        alert_response = requests.post(alert_url, json=vehicle_alert_data, headers=headers)
        alert_csv_filename = 'alert.csv'
        if alert_response.status_code == 200:
            # Parse the JSON response
            json_data = alert_response.json()
            alert_headers = json_data['result']['fields']
            with open(alert_csv_filename, 'w', newline='') as csv_file:
                csv_writer = csv.DictWriter(csv_file, fieldnames = alert_headers)
                
                # Write headers to the CSV file
                csv_writer.writeheader()
                
                # Write each JSON item as a row in the CSV file
                csv_writer.writerows(json_data['result']['output'])
        else:
            print(f"Failed to fetch the alert data. Status code: {alert_response.status_code}")
        df_alert = pd.read_csv(alert_csv_filename, encoding='unicode_escape') 
        


        
        return df_alert

def miliseconds_to_utc(time_ms):
    time_seconds = time_ms / 1000.0
    # Create a UTC datetime object
    trip_time_utc = datetime.utcfromtimestamp(time_seconds).replace(tzinfo=timezone.utc)
    formatted_trip_time_utc = trip_time_utc.strftime('%Y-%m-%dT%H:%M:%S.%fZ')

    return formatted_trip_time_utc

def utc_to_miliseconds(utc_date_string):
    # Parse the UTC date string into a datetime object
    utc_datetime = datetime.strptime(utc_date_string, '%Y-%m-%dT%H:%M:%S.%fZ')
    # Convert seconds to milliseconds
    milliseconds = int(utc_datetime.timestamp() * 1000)

    return milliseconds

# %%
# enter the start time and end time between which you want the trips for vehicles
vehicle_id = 1294352743401521152
start_ts = 1718821800000
end_ts = 1719685740000
df_dtc = fetch_dtc_data(start_ts, end_ts, vehicle_id)
# Out:
# starting timestamp  1718821800000
# ending timestamp  1718908200000
# <Response [200]>
# starting timestamp  1718908200000
# ending timestamp  1718994600000
# <Response [200]>
# starting timestamp  1718994600000
# ending timestamp  1719081000000
# <Response [200]>
# starting timestamp  1719081000000
# ending timestamp  1719167400000
# <Response [200]>
# starting timestamp  1719167400000
# ending timestamp  1719253800000
# <Response [200]>
# starting timestamp  1719253800000
# ending timestamp  1719340200000
# <Response [200]>
# starting timestamp  1719340200000
# ending timestamp  1719426600000
# <Response [200]>
# starting timestamp  1719426600000
# ending timestamp  1719513000000
# <Response [200]>
# starting timestamp  1719513000000
# ending timestamp  1719599400000
# <Response [200]>

# %%
df_dtc
# Out:
# Empty DataFrame
# Columns: [status, code, severity, vehicle_id, vehicle_id1, account_id, vehicle_plate, time, manufacturer, max_load_capacity, description]
# Index: []

# %%
# downloading the alerts and dtcs for all the vehicle_id between the start and end time-stamp
df_alert = fetch_alert_data(start_ts, end_ts, vehicle_id)
df_alert['time_miliseconds'] = df_alert['time'].apply(utc_to_miliseconds)

# %%
df_alert
# Out:
# Empty DataFrame
# Columns: [account_id, vehicle_id, severity, alert_name, time, spec_id, model, manufacturer, max_load_capacity, vehicle_id.1, time_miliseconds]
# Index: []

# %%
df_dtc = fetch_dtc_data(start_ts, end_ts)
df_dtc = df_dtc.drop_duplicates(keep='first')
df_dtc['time_miliseconds'] = df_dtc['time'].apply(utc_to_miliseconds)
# Out:
# starting timestamp  1693333800000
# ending timestamp  1693420200000
# <Response [200]>
# starting timestamp  1693506600000
# ending timestamp  1693593000000
# <Response [200]>
# starting timestamp  1693679400000
# ending timestamp  1693765800000
# <Response [200]>
# starting timestamp  1693852200000
# ending timestamp  1693938600000
# <Response [200]>
# starting timestamp  1694025000000
# ending timestamp  1694111400000
# <Response [200]>
# starting timestamp  1694197800000
# ending timestamp  1694284200000
# <Response [200]>
# starting timestamp  1694370600000
# ending timestamp  1694457000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_dtc = fetch_dtc_data(start_ts, end_ts)
#       2 df_dtc = df_dtc.drop_duplicates(keep='first')
#       3 df_dtc['time_miliseconds'] = df_dtc['time'].apply(utc_to_miliseconds)
#
# Cell In[3], line 85, in fetch_dtc_data(start_ts, end_ts)
#      25 vehicle_dtc_data = {"report": "default",
#      26     "filter":[
#      27         {
#    (...)
#      82     }
#      83     }
#      84 dtc_url = 'http://internal-apis.intangles.com/dashboard_apis/fetch'
# ---> 85 dtc_response = requests.post(dtc_url, json=vehicle_dtc_data, headers=headers)
#      86 print(dtc_response)
#      87 dtc_csv_filename = 'dtc.csv'
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File c:\ProgramData\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df_dtc = df_dtc[(df_dtc.manufacturer == manufacturer) & (df_dtc.max_load_capacity == max_load_capacity)]
df_alert = df_alert[(df_alert.manufacturer == manufacturer) & (df_alert.max_load_capacity == max_load_capacity)]
df_alert.head()
# Out:
#               account_id           vehicle_id severity  \
# 21    999705020632924160   951065816231575552    Major
# 31    993207809577320448   927139700064387072    Minor
# 49   1048293817746194432  1013067916804882432    Minor
# 63    951132064558612480   918062870334275584    Minor
# 151   914116281580388352   887606546836488192    Minor
#
#                             alert_name                      time  \
# 21   Engine operating temperature high  2023-08-31T05:48:07.000Z
# 31   Engine operating temperature high  2023-09-28T01:27:08.000Z
# 49   Engine operating temperature high  2023-09-28T00:29:29.000Z
# 63   Engine operating temperature high  2023-08-31T11:15:49.000Z
# 151  Engine operating temperature high  2023-08-30T20:15:38.000Z
#
#                  spec_id                model manufacturer  max_load_capacity  \
# 21   1027240614976028672  furio 16T cargo BS6     mahindra            16000.0
# 31    848542417341644800  furio 16T cargo BS6     mahindra            16000.0
# 49   1027240614976028672  furio 16T cargo BS6     mahindra            16000.0
# 63   1084570912415547392  furio 16T cargo BS6     mahindra            16000.0
# 151   787995314035359744  furio 16T cargo BS6     mahindra            16000.0
#
#      time_miliseconds
# 21      1693441087000
# 31      1695844628000
# 49      1695841169000
# 63      1693460749000
# 151     1693406738000

# %%
df_dtc.head()
# Out:
#     status    code  severity           vehicle_id          vehicle_id1  \
# 9   active  810-14       1.0  1000041832370929664  1000041832370929664
# 10  active   P2454       1.0  1000041832370929664  1000041832370929664
# 11  active   P2454       2.0  1000041832370929664  1000041832370929664
# 12  active   P2454       1.0  1000041832370929664  1000041832370929664
# 13  active   P2454       2.0  1000041832370929664  1000041832370929664
#
#              account_id  vehicle_plate                      time manufacturer  \
# 9   1028649932849938432  UP 75 BT 6232  2023-08-30T09:56:51.000Z     mahindra
# 10  1028649932849938432  UP 75 BT 6232  2023-08-30T01:50:49.000Z     mahindra
# 11  1028649932849938432  UP 75 BT 6232  2023-08-30T01:50:49.000Z     mahindra
# 12  1028649932849938432  UP 75 BT 6232  2023-08-29T18:48:16.000Z     mahindra
# 13  1028649932849938432  UP 75 BT 6232  2023-08-29T18:48:16.000Z     mahindra
#
#     max_load_capacity                                        description  \
# 9             16000.0                                 Speed Signal Input
# 10            16000.0  Particulate Filter Pressure sensor output belo...
# 11            16000.0  Particulate Filter Pressure sensor output belo...
# 12            16000.0  Particulate Filter Pressure sensor output belo...
# 13            16000.0  Particulate Filter Pressure sensor output belo...
#
#     time_miliseconds
# 9      1693369611000
# 10     1693340449000
# 11     1693340449000
# 12     1693315096000
# 13     1693315096000

# %%
# getting the alerts and trips mapped
unique_vehicles = df_alert.vehicle_id.unique().tolist()
print(len(unique_vehicles))
df_all_trip_alerts = pd.DataFrame()
count = 0
for vehicle_idx in range(len(unique_vehicles)):
    # downloading all the trips of the vehicle_id between the start and end time-stamp
    vehicle = unique_vehicles[vehicle_idx]
    trip_json_data = trip_data_download(vehicle, start_ts, end_ts)
    # Convert JSON data to a DataFrame
    df_vehicle_trips = pd.DataFrame(trip_json_data)
    df_vehicle_alerts = df_alert[(df_alert.vehicle_id == vehicle)]

    if (df_vehicle_alerts.shape[0] >0) and (df_vehicle_trips.shape[0] > 0):
        for alert_idx in range(0, df_vehicle_alerts.shape[0]):
            time_alert = df_vehicle_alerts.iloc[alert_idx]['time_miliseconds']
            df_alert_trip = df_vehicle_trips.loc[(df_vehicle_trips['start_time'] <= time_alert) &
                                                   (df_vehicle_trips['end_time'] >= time_alert)]
           
           
            df_vehicle_alert = df_vehicle_alerts.iloc[alert_idx].to_frame().T
        
           
         
            if df_alert_trip.shape[0]>0:
                #df_all_trip_alerts= pd.concat([df_all_trip_alerts, df_alert_concat], ignore_index=True)
                df_temp_alert = pd.DataFrame({"Trip_ID" : [df_alert_trip.iloc[0]['_id']],
                                                "Start_Time" : [df_alert_trip.iloc[0]['start_time']],
                                                "End_Time" : [df_alert_trip.iloc[0]['end_time']],
                                                "Predictive_alerts" : [df_vehicle_alert.iloc[0]['alert_name']],
                                                "severity": [df_vehicle_alert.iloc[0]['severity']],
                                                "time_of alert": [df_vehicle_alert.iloc[0]['time']],
                                                "model": [df_vehicle_alert.iloc[0]['model']],
                                                "manufacturer": [df_vehicle_alert.iloc[0]['manufacturer']],
                                                "max_load_capacity": [df_vehicle_alert.iloc[0]['max_load_capacity']]
                                                 
                                                
                                              })

                
                df_all_trip_alerts= pd.concat([df_all_trip_alerts, df_temp_alert], ignore_index=True)
# Out:
# 236

# %%
# getting the alerts and trips mapped
df_all_trip_dtcs = pd.DataFrame()
# getting the unique vehicles
unique_vehicles = df_dtc.vehicle_id.unique().tolist()
print(len(unique_vehicles))
count = 0
for vehicle_idx in range(len(unique_vehicles)):
    # downloading all the trips of the vehicle_id between the start and end time-stamp
    vehicle = unique_vehicles[vehicle_idx]
    print(vehicle)
    trip_json_data = trip_data_download(vehicle, start_ts, end_ts)
    if len(trip_json_data)>0:
        # Convert JSON data to a DataFrame
        df_vehicle_trips = pd.DataFrame(trip_json_data)
        df_vehicle_dtcs = df_dtc[(df_dtc.vehicle_id == vehicle)]
        if (df_vehicle_dtcs.shape[0] >0) and (df_vehicle_trips.shape[0] > 0):
            for alert_idx in range(0, df_vehicle_dtcs.shape[0]):
                time_dtc = df_vehicle_dtcs.iloc[alert_idx]['time_miliseconds']
                df_dtc_trip = df_vehicle_trips.loc[(df_vehicle_trips['start_time'] <= time_dtc) &
                                                    (df_vehicle_trips['end_time'] >= time_dtc)]
            
                df_vehicle_dtc = df_vehicle_dtcs.iloc[alert_idx].to_frame().T
            
            
            
                if df_dtc_trip.shape[0]>0:
        
                    df_temp_dtc = pd.DataFrame({"Trip_ID" : [df_dtc_trip.iloc[0]['_id']] ,
                                                    "Start_Time" : [df_dtc_trip.iloc[0]['start_time']],
                                                    "End_Time" : [df_dtc_trip.iloc[0]['end_time']],
                                                    "DTC" : [df_vehicle_dtc.iloc[0]['code']],
                                                    "status": [df_vehicle_dtc.iloc[0]['status']],
                                                    "time_of_dtc": [df_vehicle_dtc.iloc[0]['time']],
                                                    "description" : [df_vehicle_dtc.iloc[0]['description']]
                                                    
                                                    
                                                })
                    
                    df_all_trip_dtcs= pd.concat([df_all_trip_dtcs, df_temp_dtc], ignore_index=True)
    print("this is the vehicle index", vehicle_idx)
# Out:
# 533
# 1000041832370929664
# this is the vehicle index 0
# 1001786996651196416
# this is the vehicle index 1
# 1002155382019194880
# this is the vehicle index 2
# 1004323703212736512
# this is the vehicle index 3
# 1003204815926329344
# this is the vehicle index 4
# 1008371704788942848
# this is the vehicle index 5
# 1009400932716249088
# this is the vehicle index 6
# 1012625060713725952
# this is the vehicle index 7
# 1012994619849310208
# this is the vehicle index 8
# 1012995656710619136
# this is the vehicle index 9
# 1013396739543007232
# this is the vehicle index 10
# 1015566071555424256
# this is the vehicle index 11
# 1016287725000589312
# this is the vehicle index 12
# 1016336951592091648
# this is the vehicle index 13
# 1016337068688670720
# this is the vehicle index 14
# 1020634464985808896
# this is the vehicle index 15
# 1023211883932418048
# this is the vehicle index 16
# 1023160470560833536
# this is the vehicle index 17
# 1027849379412705280
# this is the vehicle index 18
# 1038357273237258240
# this is the vehicle index 19
# 1038357867746295808
# this is the vehicle index 20
# 1046065169077108736
# this is the vehicle index 21
# 1055794084993564672
# this is the vehicle index 22
# 1057567072793395200
# this is the vehicle index 23
# 1058010693195792384
# this is the vehicle index 24
# 1058010601688662016
# this is the vehicle index 25
# 1061903809346797568
# this is the vehicle index 26
# 1065212175703867392
# this is the vehicle index 27
# 1067057944715067392
# this is the vehicle index 28
# 1069886217388032000
# this is the vehicle index 29
# 1069983286098395136
# this is the vehicle index 30
# 1071003536063463424
# this is the vehicle index 31
# 1071739221233893376
# this is the vehicle index 32
# 1072116940715065344
# this is the vehicle index 33
# 1072775243409391616
# this is the vehicle index 34
# 1076063317123923968
# this is the vehicle index 35
# 1080411342801731584
# this is the vehicle index 36
# 1081880172027707392
# this is the vehicle index 37
# 1100043412612055040
# this is the vehicle index 38
# 1101503538841780224
# this is the vehicle index 39
# 1107593534334042112
# this is the vehicle index 40
# 1108296493606895616
# this is the vehicle index 41
# 1113390176970735616
# this is the vehicle index 42
# 1117352619203887104
# this is the vehicle index 43
# 1135116102037143552
# this is the vehicle index 44
# 776458476992856064
# this is the vehicle index 45
# 799893039622389760
# this is the vehicle index 46
# 813421045934456832
# this is the vehicle index 47
# 818491445454307328
# this is the vehicle index 48
# 832180282227425280
# this is the vehicle index 49
# 832598395775352832
# this is the vehicle index 50
# 834009952908476416
# this is the vehicle index 51
# 853255915149721600
# this is the vehicle index 52
# 859747405896089600
# this is the vehicle index 53
# 860159566229274624
# this is the vehicle index 54
# 860411797520252928
# this is the vehicle index 55
# 870959246722727936
# this is the vehicle index 56
# 870962584625348608
# this is the vehicle index 57
# 872767005822812160
# this is the vehicle index 58
# 873505907277824000
# this is the vehicle index 59
# 874924312564334592
# this is the vehicle index 60
# 880351481935429632
# this is the vehicle index 61
# 884074280126513152
# this is the vehicle index 62
# 886325904500850688
# this is the vehicle index 63
# 886626131552239616
# this is the vehicle index 64
# 888751294792073216
# this is the vehicle index 65
# 895289899551293440
# this is the vehicle index 66
# 895222886258704384
# this is the vehicle index 67
# 895289306325712896
# this is the vehicle index 68
# 896342828714557440
# this is the vehicle index 69
# 896381429867347968
# this is the vehicle index 70
# 896388897599127552
# this is the vehicle index 71
# 896689338937507840
# this is the vehicle index 72
# 897736703005949952
# this is the vehicle index 73
# 903544993262600192
# this is the vehicle index 74
# 909081101245349888
# this is the vehicle index 75
# 923471757443072000
# this is the vehicle index 76
# 924927188724088832
# this is the vehicle index 77
# 924926856992391168
# this is the vehicle index 78
# 927139700064387072
# this is the vehicle index 79
# 927144399052210176
# this is the vehicle index 80
# 927169571939418112
# this is the vehicle index 81
# 936966039432855552
# this is the vehicle index 82
# 940165047097753600
# this is the vehicle index 83
# 941949028415832064
# this is the vehicle index 84
# 951065816231575552
# this is the vehicle index 85
# 951418193505681408
# this is the vehicle index 86
# 952460979059294208
# this is the vehicle index 87
# 953929148420587520
# this is the vehicle index 88
# 953928816097492992
# this is the vehicle index 89
# 954347246097268736
# this is the vehicle index 90
# 954347345812652032
# this is the vehicle index 91
# 955106138246873088
# this is the vehicle index 92
# 959362161975492608
# this is the vehicle index 93
# 961186156043567104
# this is the vehicle index 94
# 961186318082113536
# this is the vehicle index 95
# 964794352821862400
# this is the vehicle index 96
# 969508901621858304
# this is the vehicle index 97
# 973127614279450624
# this is the vehicle index 98
# 980092800462749696
# this is the vehicle index 99
# 982899708357771264
# this is the vehicle index 100
# 982956117350940672
# this is the vehicle index 101
# 984101209306562560
# this is the vehicle index 102
# 985471071140446208
# this is the vehicle index 103
# 985894500243079168
# this is the vehicle index 104
# 986921185847541760
# this is the vehicle index 105
# 988380130470526976
# this is the vehicle index 106
# 988380206664253440
# this is the vehicle index 107
# 991669086213636096
# this is the vehicle index 108
# 991669207768760320
# this is the vehicle index 109
# 992760100663853056
# this is the vehicle index 110
# 992760365559316480
# this is the vehicle index 111
# 992760516298407936
# this is the vehicle index 112
# 995238337952350208
# this is the vehicle index 113
# 997477963270193152
# this is the vehicle index 114
# 998133834945921024
# this is the vehicle index 115
# 998134026222960640
# this is the vehicle index 116
# 1004698451495092224
# this is the vehicle index 117
# 1005480669645635584
# this is the vehicle index 118
# 1005480923052900352
# this is the vehicle index 119
# 1007594721217871872
# this is the vehicle index 120
# 1011971752005206016
# this is the vehicle index 121
# 1013067916804882432
# this is the vehicle index 122
# 1015897840276209664
# this is the vehicle index 123
# 1020634553762447360
# this is the vehicle index 124
# 1022817570249506816
# this is the vehicle index 125
# 1025330574396489728
# this is the vehicle index 126
# 1028560217429770240
# this is the vehicle index 127
# 1028658023838515200
# this is the vehicle index 128
# 1035896181403680768
# this is the vehicle index 129
# 1046737022233870336
# this is the vehicle index 130
# 1050420102224150528
# this is the vehicle index 131
# 1051049653006499840
# this is the vehicle index 132
# 1053678023334690816
# this is the vehicle index 133
# 1055746350005616640
# this is the vehicle index 134
# 1056868616957329408
# this is the vehicle index 135
# 1057569611634966528
# this is the vehicle index 136
# 1055469924538908672
# this is the vehicle index 137
# 1056100772162306048
# this is the vehicle index 138
# 1058011621516902400
# this is the vehicle index 139
# 1061903634524012544
# this is the vehicle index 140
# 1061904362894262272
# this is the vehicle index 141
# 1067058057575399424
# this is the vehicle index 142
# 1067771256188698624
# this is the vehicle index 143
# 1071742675356483584
# this is the vehicle index 144
# 1070275438225391616
# this is the vehicle index 145
# 1070636441530269696
# this is the vehicle index 146
# 1093468343806984192
# this is the vehicle index 147
# 1114498324825636864
# this is the vehicle index 148
# 1126081465474351104
# this is the vehicle index 149
# 1126132744120696832
# this is the vehicle index 150
# 1137640985623265280
# this is the vehicle index 151
# 849980124446064640
# this is the vehicle index 152
# 852160704239632384
# this is the vehicle index 153
# 853270360391417856
# this is the vehicle index 154
# 855782937575030784
# this is the vehicle index 155
# 876014021067669504
# this is the vehicle index 156
# 880745737887940608
# this is the vehicle index 157
# 882563398837993472
# this is the vehicle index 158
# 895610277892980736
# this is the vehicle index 159
# 896689478259703808
# this is the vehicle index 160
# 896370646408232960
# this is the vehicle index 161
# 896688368878878720
# this is the vehicle index 162
# 923471890553503744
# this is the vehicle index 163
# 924927292596027392
# this is the vehicle index 164
# 924927404147736576
# this is the vehicle index 165
# 909081254253559808
# this is the vehicle index 166
# 918062870334275584
# this is the vehicle index 167
# 927171501449281536
# this is the vehicle index 168
# 933991011565174784
# this is the vehicle index 169
# 952460097806663680
# this is the vehicle index 170
# 952543128118624256
# this is the vehicle index 171
# 954284182463315968
# this is the vehicle index 172
# 955067616936853504
# this is the vehicle index 173
# 956878270542905344
# this is the vehicle index 174
# 961571004763602944
# this is the vehicle index 175
# 961571742323572736
# this is the vehicle index 176
# 961570708993867776
# this is the vehicle index 177
# 961939126569926656
# this is the vehicle index 178
# 970288602112065536
# this is the vehicle index 179
# 972873084996419584
# this is the vehicle index 180
# 982899811780919296
# this is the vehicle index 181
# 990512914651676672
# this is the vehicle index 182
# 986922147093938176
# this is the vehicle index 183
# 997763392926121984
# this is the vehicle index 184
# 1001787150187888640
# this is the vehicle index 185
# 1002113888004603904
# this is the vehicle index 186
# 1007594907474329600
# this is the vehicle index 187
# 1009400809013641216
# this is the vehicle index 188
# 1020686417593892864
# this is the vehicle index 189
# 1022040547390390272
# this is the vehicle index 190
# 1027185334959472640
# this is the vehicle index 191
# 1035896624510926848
# this is the vehicle index 192
# 1041247687057342464
# this is the vehicle index 193
# 1046064927086739456
# this is the vehicle index 194
# 1046403577787973632
# this is the vehicle index 195
# 1048239667540918272
# this is the vehicle index 196
# 1050364477590994944
# this is the vehicle index 197
# 1050476681371844608
# this is the vehicle index 198
# 1053565034279469056
# this is the vehicle index 199
# 1056521578252075008
# this is the vehicle index 200
# 1057568034371141632
# this is the vehicle index 201
# 1061904114864095232
# this is the vehicle index 202
# 1067704677581193216
# this is the vehicle index 203
# 1071368136206319616
# this is the vehicle index 204
# 1092399162139344896
# this is the vehicle index 205
# 1092399611164753920
# this is the vehicle index 206
# 1114817455030534144
# this is the vehicle index 207
# 1132578895271297024
# this is the vehicle index 208
# 1137687900876439552
# this is the vehicle index 209
# 1138104606321016832
# this is the vehicle index 210
# 804294813175250944
# this is the vehicle index 211
# 837946760599961600
# this is the vehicle index 212
# 855782684922740736
# this is the vehicle index 213
# 884074169430441984
# this is the vehicle index 214
# 884074398263279616
# this is the vehicle index 215
# 888750914268037120
# this is the vehicle index 216
# 888765210280591360
# this is the vehicle index 217
# 886578492848734208
# this is the vehicle index 218
# 895289394850693120
# this is the vehicle index 219
# 896688994455126016
# this is the vehicle index 220
# 896688093929668608
# this is the vehicle index 221
# 924926726243352576
# this is the vehicle index 222
# 933990879197134848
# this is the vehicle index 223
# 936966913701969920
# this is the vehicle index 224
# 944936232570322944
# this is the vehicle index 225
# 930038233721470976
# this is the vehicle index 226
# 955464369905336320
# this is the vehicle index 227
# 950731353400279040
# this is the vehicle index 228
# 951418072458067968
# this is the vehicle index 229
# 973922147057532928
# this is the vehicle index 230
# 961939359932612608
# this is the vehicle index 231
# 980092708213227520
# this is the vehicle index 232
# 982956237085736960
# this is the vehicle index 233
# 984100970369646592
# this is the vehicle index 234
# 985471238589644800
# this is the vehicle index 235
# 988380275127877632
# this is the vehicle index 236
# 994511467996774400
# this is the vehicle index 237
# 1001786701745487872
# this is the vehicle index 238
# 1004698604650102784
# this is the vehicle index 239
# 1004698749194207232
# this is the vehicle index 240
# 1005735651997384704
# this is the vehicle index 241
# 1012624736053624832
# this is the vehicle index 242
# 1016337580909658112
# this is the vehicle index 243
# 956878013469818880
# this is the vehicle index 244
# 1032561141638758400
# this is the vehicle index 245
# 952460562132893696
# this is the vehicle index 246
# 1046065048566366208
# this is the vehicle index 247
# 1051050069844819968
# this is the vehicle index 248
# 1058011440754982912
# this is the vehicle index 249
# 982900014198030336
# this is the vehicle index 250
# 1137653898442440704
# this is the vehicle index 251
# 1069886473349627904
# this is the vehicle index 252
# 1077884000225198080
# this is the vehicle index 253
# 1082627104564051968
# this is the vehicle index 254
# 896687980092063744
# this is the vehicle index 255
# 1117352486806487040
# this is the vehicle index 256
# 952461897553149952
# this is the vehicle index 257
# 1127186723147612160
# this is the vehicle index 258
# 1134096380386607104
# this is the vehicle index 259
# 1143849665662287872
# this is the vehicle index 260
# 800998774544531456
# this is the vehicle index 261
# 816580777784377344
# this is the vehicle index 262
# 822459191632330752
# this is the vehicle index 263
# 834023578780303360
# this is the vehicle index 264
# 872480645245304832
# this is the vehicle index 265
# 872754537683746816
# this is the vehicle index 266
# 888372926938611712
# this is the vehicle index 267
# 895289654360670208
# this is the vehicle index 268
# 917399113635463168
# this is the vehicle index 269
# 951372130879012864
# this is the vehicle index 270
# 953929300292141056
# this is the vehicle index 271
# 955106014108057600
# this is the vehicle index 272
# 961570910454677504
# this is the vehicle index 273
# 990512512355008512
# this is the vehicle index 274
# 1002113783419633664
# this is the vehicle index 275
# 1002155275517427712
# this is the vehicle index 276
# 1003204380075229184
# this is the vehicle index 277
# 1004698842139983872
# this is the vehicle index 278
# 1027536356181540864
# this is the vehicle index 279
# 1050419787357749248
# this is the vehicle index 280
# 1061903877210636288
# this is the vehicle index 281
# 1055746086083231744
# this is the vehicle index 282
# 1063355436612190208
# this is the vehicle index 283
# 1139186024300150784
# this is the vehicle index 284
# 808673396538736640
# this is the vehicle index 285
# 843838547499679744
# this is the vehicle index 286
# 855782583303143424
# this is the vehicle index 287
# 872478805548072960
# this is the vehicle index 288
# 905408096065552384
# this is the vehicle index 289
# 914411077356224512
# this is the vehicle index 290
# 924926994569756672
# this is the vehicle index 291
# 930038133997699072
# this is the vehicle index 292
# 954725164900155392
# this is the vehicle index 293
# 980726697986883584
# this is the vehicle index 294
# 980727153890951168
# this is the vehicle index 295
# 992760433087610880
# this is the vehicle index 296
# 1015565790079877120
# this is the vehicle index 297
# 1027849700650254336
# this is the vehicle index 298
# 1027849925087461376
# this is the vehicle index 299
# 1027850147809198080
# this is the vehicle index 300
# 1049952773975572480
# this is the vehicle index 301
# 1049953243263664128
# this is the vehicle index 302
# 1055470038422650880
# this is the vehicle index 303
# 1064452772985831424
# this is the vehicle index 304
# 1072117297419649024
# this is the vehicle index 305
# 1071003741647273984
# this is the vehicle index 306
# 1073908069408178176
# this is the vehicle index 307
# 1076063241722920960
# this is the vehicle index 308
# 856544797974855680
# this is the vehicle index 309
# 860449674069278720
# this is the vehicle index 310
# 872485620184776704
# this is the vehicle index 311
# 883355605627043840
# this is the vehicle index 312
# 896346235793833984
# this is the vehicle index 313
# 903544872399536128
# this is the vehicle index 314
# 930038424600051712
# this is the vehicle index 315
# 931167170556067840
# this is the vehicle index 316
# 951065684211662848
# this is the vehicle index 317
# 992760697836273664
# this is the vehicle index 318
# 998134800034299904
# this is the vehicle index 319
# 1022494722377121792
# this is the vehicle index 320
# 1021429019075149824
# this is the vehicle index 321
# 1056521062478512128
# this is the vehicle index 322
# 1046739320838291456
# this is the vehicle index 323
# 1063060336753508352
# this is the vehicle index 324
# 1068083064673927168
# this is the vehicle index 325
# 1069983202627551232
# this is the vehicle index 326
# 1070275332239523840
# this is the vehicle index 327
# 1114498581705785344
# this is the vehicle index 328
# 1115253919367299072
# this is the vehicle index 329
# 1128689777663541248
# this is the vehicle index 330
# 1202260894071914496
# this is the vehicle index 331
# 830383751648247808
# this is the vehicle index 332
# 939508755333120000
# this is the vehicle index 333
# 944932078430978048
# this is the vehicle index 334
# 990195969909850112
# this is the vehicle index 335
# 990196370272944128
# this is the vehicle index 336
# 992760234596368384
# this is the vehicle index 337
# 1004323812004593664
# this is the vehicle index 338
# 1010084376513347584
# this is the vehicle index 339
# 1036258186371268608
# this is the vehicle index 340
# 1041248050414092288
# this is the vehicle index 341
# 1067704577379270656
# this is the vehicle index 342
# 1072116298160275456
# this is the vehicle index 343
# 1076063385025511424
# this is the vehicle index 344
# 1146357052717662208
# this is the vehicle index 345
# 1177199555813310464
# this is the vehicle index 346
# 1203340654478884864
# this is the vehicle index 347
# 808673288942256128
# this is the vehicle index 348
# 855782505209397248
# this is the vehicle index 349
# 887606546836488192
# this is the vehicle index 350
# 896688226524200960
# this is the vehicle index 351
# 933991211235016704
# this is the vehicle index 352
# 951065294330134528
# this is the vehicle index 353
# 953981839310061568
# this is the vehicle index 354
# 953981934684340224
# this is the vehicle index 355
# 973127238813745152
# this is the vehicle index 356
# 982899399128514560
# this is the vehicle index 357
# 985894616479825920
# this is the vehicle index 358
# 990196081042128896
# this is the vehicle index 359
# 1022494593272250368
# this is the vehicle index 360
# 1028657887846596608
# this is the vehicle index 361
# 1039867324611428352
# this is the vehicle index 362
# 1050725698932572160
# this is the vehicle index 363
# 1055794600133787648
# this is the vehicle index 364
# 1068168016933421056
# this is the vehicle index 365
# 1071003456640122880
# this is the vehicle index 366
# 1089137951138381824
# this is the vehicle index 367
# 1134034348303974400
# this is the vehicle index 368
# 1129683228400025600
# this is the vehicle index 369
# 1134409430666838016
# this is the vehicle index 370
# 1139185005524680704
# this is the vehicle index 371
# 860411885579665408
# this is the vehicle index 372
# 952202211851501568
# this is the vehicle index 373
# 985106787675930624
# this is the vehicle index 374
# 992760808121303040
# this is the vehicle index 375
# 1053678215580614656
# this is the vehicle index 376
# 1076063089004118016
# this is the vehicle index 377
# 1083008489371992064
# this is the vehicle index 378
# 1138407872569278464
# this is the vehicle index 379
# 1143850052209344512
# this is the vehicle index 380
# 840524333041319936
# this is the vehicle index 381
# 853255646869454848
# this is the vehicle index 382
# 881540064889274368
# this is the vehicle index 383
# 898562166905372672
# this is the vehicle index 384
# 936966228692434944
# this is the vehicle index 385
# 954724685717700608
# this is the vehicle index 386
# 973922828648710144
# this is the vehicle index 387
# 1013396507694465024
# this is the vehicle index 388
# 1046403343464792064
# this is the vehicle index 389
# 1058338097386749952
# this is the vehicle index 390
# 1071003650253389824
# this is the vehicle index 391
# 1071739641322799104
# this is the vehicle index 392
# 954724778168549376
# this is the vehicle index 393
# 1118477674591813632
# this is the vehicle index 394
# 1205772061205594112
# this is the vehicle index 395
# 863728835244326912
# this is the vehicle index 396
# 1022040687585001472
# this is the vehicle index 397
# 1027535992908677120
# this is the vehicle index 398
# 1037983434712023040
# this is the vehicle index 399
# 1063060234035003392
# this is the vehicle index 400
# 1066974215602700288
# this is the vehicle index 401
# 997763243537596416
# this is the vehicle index 402
# 999314757645238272
# this is the vehicle index 403
# 1028658226867994624
# this is the vehicle index 404
# 1069546922861133824
# this is the vehicle index 405
# 1069886570921721856
# this is the vehicle index 406
# 1070276079735799808
# this is the vehicle index 407
# 1082626915300278272
# this is the vehicle index 408
# 1113390556177760256
# this is the vehicle index 409
# 1114456205255770112
# this is the vehicle index 410
# 1135219011433267200
# this is the vehicle index 411
# 979722141047980032
# this is the vehicle index 412
# 997477853085827072
# this is the vehicle index 413
# 1022037618545655808
# this is the vehicle index 414
# 1056521679389327360
# this is the vehicle index 415
# 1039869496996659200
# this is the vehicle index 416
# 1128689617332076544
# this is the vehicle index 417
# 1137721409389199360
# this is the vehicle index 418
# 1150799188636729344
# this is the vehicle index 419
# 1150799305632645120
# this is the vehicle index 420
# 1151452585597599744
# this is the vehicle index 421
# 1196402665127411712
# this is the vehicle index 422
# 969508721988206592
# this is the vehicle index 423
# 982557445391908864
# this is the vehicle index 424
# 984356938357669888
# this is the vehicle index 425
# 991669297522671616
# this is the vehicle index 426
# 1012624894053056512
# this is the vehicle index 427
# 1022494872839389184
# this is the vehicle index 428
# 1047772305209425920
# this is the vehicle index 429
# 1056520877299990528
# this is the vehicle index 430
# 1071368061711286272
# this is the vehicle index 431
# 1108296585734782976
# this is the vehicle index 432
# 1137721700788469760
# this is the vehicle index 433
# 881524843705532416
# this is the vehicle index 434
# 895223576284626944
# this is the vehicle index 435
# 942405710774272000
# this is the vehicle index 436
# 954724425255616512
# this is the vehicle index 437
# 961939032915312640
# this is the vehicle index 438
# 982557540787159040
# this is the vehicle index 439
# 990510873707544576
# this is the vehicle index 440
# 1020686600759148544
# this is the vehicle index 441
# 1071368003599204352
# this is the vehicle index 442
# 848497401814581248
# this is the vehicle index 443
# 927171388567977984
# this is the vehicle index 444
# 954284397492699136
# this is the vehicle index 445
# 998133933214269440
# this is the vehicle index 446
# 1012251796443234304
# this is the vehicle index 447
# 1027537157922750464
# this is the vehicle index 448
# 1028658135348281344
# this is the vehicle index 449
# 1041248142839775232
# this is the vehicle index 450
# 1048575551075254272
# this is the vehicle index 451
# 1070636683424169984
# this is the vehicle index 452
# 990512729468960768
# this is the vehicle index 453
# 1127185553649827840
# this is the vehicle index 454
# 1135219341197836288
# this is the vehicle index 455
# 1001830804256456704
# this is the vehicle index 456
# 1071368327764377600
# this is the vehicle index 457
# 1071739550897799168
# this is the vehicle index 458
# 1194968053025079296
# this is the vehicle index 459
# 888758723256778752
# this is the vehicle index 460
# 950357214688706560
# this is the vehicle index 461
# 954724520353071104
# this is the vehicle index 462
# 994219907098869760
# this is the vehicle index 463
# 1015934715263188992
# this is the vehicle index 464
# 1032561336980078592
# this is the vehicle index 465
# 1046403437933101056
# this is the vehicle index 466
# 1064452447793053696
# this is the vehicle index 467
# 1117352351250776064
# this is the vehicle index 468
# 1206222397787602944
# this is the vehicle index 469
# 776793972801536000
# this is the vehicle index 470
# 835840860695298048
# this is the vehicle index 471
# 870980658732728320
# this is the vehicle index 472
# 930037971116097536
# this is the vehicle index 473
# 1019951044546789376
# this is the vehicle index 474
# 1022803959707860992
# this is the vehicle index 475
# 1114498952356429824
# this is the vehicle index 476
# 1116329666987163648
# this is the vehicle index 477
# 880063814823837696
# this is the vehicle index 478
# 1000728687223504896
# this is the vehicle index 479
# 1008371457585053696
# this is the vehicle index 480
# 1027849545242902528
# this is the vehicle index 481
# 1036258395004338176
# this is the vehicle index 482
# 1048575455482871808
# this is the vehicle index 483
# 1056214660031709184
# this is the vehicle index 484
# 1162764423819952128
# this is the vehicle index 485
# 802186524757065728
# this is the vehicle index 486
# 871645600943177728
# this is the vehicle index 487
# 1007595068955033600
# this is the vehicle index 488
# 1063060486741819392
# this is the vehicle index 489
# 1177199737929990144
# this is the vehicle index 490
# 1013396847164653568
# this is the vehicle index 491
# 1077883908395106304
# this is the vehicle index 492
# 858619913500098560
# this is the vehicle index 493
# 936645106230886400
# this is the vehicle index 494
# 1049314861508460544
# this is the vehicle index 495
# 1061904213719646208
# this is the vehicle index 496
# 1012251920007430144
# this is the vehicle index 497
# 895289526455369728
# this is the vehicle index 498
# 985471149682982912
# this is the vehicle index 499
# 1114817333873868800
# this is the vehicle index 500
# 880055879246807040
# this is the vehicle index 501
# 915971304274788352
# this is the vehicle index 502
# 1196030897137123328
# this is the vehicle index 503
# 870980505430917120
# this is the vehicle index 504
# 883301906565300224
# this is the vehicle index 505
# 950356891886682112
# this is the vehicle index 506
# 951372606466949120
# this is the vehicle index 507
# 1002113647658401792
# this is the vehicle index 508
# 1048575142852034560
# this is the vehicle index 509
# 1057569131932418048
# this is the vehicle index 510
# 1068520092511240192
# this is the vehicle index 511
# 1069983021500727296
# this is the vehicle index 512
# 1072117216436027392
# this is the vehicle index 513
# 1113389661364944896
# this is the vehicle index 514
# 875384007112523776
# this is the vehicle index 515
# 895223132376268800
# this is the vehicle index 516
# 1069546806217539584
# this is the vehicle index 517
# 1135115887573991424
# this is the vehicle index 518
# 1082627331173908480
# this is the vehicle index 519
# 1139203716591648768
# this is the vehicle index 520
# 1127185884769157120
# this is the vehicle index 521
# 1138750271699025920
# this is the vehicle index 522
# 886260714304438272
# this is the vehicle index 523
# 1070636536489312256
# this is the vehicle index 524
# 1194917248238616576
# this is the vehicle index 525
# 1012994852490575872
# this is the vehicle index 526
# 1097416699965079552
# this is the vehicle index 527
# 1046403197263937536
# this is the vehicle index 528
# 1048575259617263616
# this is the vehicle index 529
# 1196031073478246400
# this is the vehicle index 530
# 1220004729350782976
# this is the vehicle index 531
# 1080850180657381376
# this is the vehicle index 532

# %%
df_all_trip_dtcs.head()
# Out:
#                                              Trip_ID     Start_Time  \
# 0  1693369590000-1028649932849938432-100004183237...  1693369590000
# 1  1693337776000-1028649932849938432-100004183237...  1693337776000
# 2  1693337776000-1028649932849938432-100004183237...  1693337776000
# 3  1693369590000-1028649932849938432-100004183237...  1693369590000
# 4  1693337776000-1028649932849938432-100004183237...  1693337776000
#
#        End_Time     DTC  status               time_of_dtc  \
# 0  1.693371e+12  810-14  active  2023-08-30T09:56:51.000Z
# 1  1.693342e+12   P2454  active  2023-08-30T01:50:49.000Z
# 2  1.693342e+12   P2454  active  2023-08-30T01:50:49.000Z
# 3  1.693371e+12  810-14  active  2023-08-30T09:56:51.000Z
# 4  1.693342e+12   P2454  active  2023-08-30T01:50:49.000Z
#
#                                          description
# 0                                 Speed Signal Input
# 1  Particulate Filter Pressure sensor output belo...
# 2  Particulate Filter Pressure sensor output belo...
# 3                                 Speed Signal Input
# 4  Particulate Filter Pressure sensor output belo...

# %%
# getting the count of common trips with both dtcs and alerts
vehicle_alerts = df_all_trip_alerts.Trip_ID.unique().tolist()
vehicle_dtcs = df_all_trip_dtcs.Trip_ID.unique().tolist()
common_trips = list(set(vehicle_alerts).intersection(vehicle_dtcs))
print(len(common_trips))
# Out:
# 14

# %%
# joining the alert and dtc trips sharing the same Trip_ID
df_all_trip_alerts_dtcs = pd.merge(df_all_trip_alerts, df_all_trip_dtcs, on = ['Trip_ID', 'Start_Time', 'End_Time'], how= 'outer')

# %%
df_all_trip_alerts_dtcs.head()
# Out:
#                                              Trip_ID     Start_Time  \
# 0  1693460631000-951132064558612480-9180628703342...  1693460631000
# 1  1693360388000-951132064558612480-9180628703342...  1693360388000
# 2  1693456859000-1028649932849938432-100004183237...  1693456859000
# 3  1697311906000-1028649932849938432-100004183237...  1697311906000
# 4  1697128633000-1028649932849938432-100004183237...  1697128633000
#
#        End_Time                  Predictive_alerts severity  \
# 0  1.693462e+12  Engine operating temperature high    Minor
# 1  1.693366e+12  Engine operating temperature high    Major
# 2  1.693470e+12  Engine operating temperature high    Minor
# 3  1.697316e+12  Engine operating temperature high    Major
# 4  1.697137e+12  Engine operating temperature high    Major
#
#               time_of alert                model manufacturer  \
# 0  2023-08-31T11:15:49.000Z  furio 16T cargo BS6     mahindra
# 1  2023-08-30T08:22:42.000Z  furio 16T cargo BS6     mahindra
# 2  2023-08-31T11:51:51.000Z  furio 16T cargo BS6     mahindra
# 3  2023-10-15T01:58:23.000Z  furio 16T cargo BS6     mahindra
# 4  2023-10-12T23:38:40.000Z  furio 16T cargo BS6     mahindra
#
#    max_load_capacity    DTC  status               time_of_dtc  \
# 0            16000.0    NaN     NaN                       NaN
# 1            16000.0    NaN     NaN                       NaN
# 2            16000.0    NaN     NaN                       NaN
# 3            16000.0    NaN     NaN                       NaN
# 4            16000.0  P2183  active  2023-10-13T00:04:09.000Z
#
#                                          description
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Measured value of Coolant Temperature above limit

# %%
df_all_trip_alerts_dtcs.to_csv(os.path.join(output_path, "Trip_dtc_alerts.csv"))
